# %% [markdown]
# # Scraping into text file

# %%
import requests
from bs4 import BeautifulSoup

# %%
L = "https://books.toscrape.com/index.html"
f = open('book.txt', 'w+', encoding="utf-8")

# %%
def Link_Of_Page(LINK):
    response = requests.get(LINK)
    soup = BeautifulSoup(response.text,"html.parser")
    catalogue = soup.find_all('a')
    link=[]
    for c in catalogue:
        link.append(c.attrs['href'])
    link = link[3:53]
    return link

# %%
link=Link_Of_Page(L)
rates = {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5}

# %%
def Details_Category(i):
    url=f"https://books.toscrape.com/{link[i]}"
    response=requests.get(url)
    soup=BeautifulSoup(response.text,"html.parser")
    art =soup.find_all('article',attrs={"class":"product_pod"})
    Name=soup.find('ul',attrs={'class':'nav nav-list'}).find_all('li')[i+1].find('a').get_text().strip()
    print(f'Name Of Category: {Name}')
    print(f'Link Of Category: {url}')
    print('*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*')
    return art,soup,Name,url

# %%
def Details_Book(link_):
    response=requests.get(link_)
    SOUP=BeautifulSoup(response.text,"html.parser")
    quantity=SOUP.find('table',attrs={'class':'table table-striped'}).find_all('tr')[5].find('td').get_text()
    quantity=quantity.split()
    quantity=quantity[2][1:]
    return quantity

# %%
def Details_Page(j):
    name =j.find('h3').find('a')['title']
    price=float(j.find('p',attrs={"class":"price_color"}).get_text().split('£')[1])
    rate =j.find('p').get('class')[1]
    l=j.find('h3').find('a').get('href')
    l=l.split('../')
    l=''.join(l)
    link_ =f"https://books.toscrape.com/catalogue/{l}"
    quantity=Details_Book(link_)
    print(f'Book name: {name}\nPrice: {price}\nRate: {rates[rate]}\nBook link: {link_}\nquantity: {quantity}\n')
    print('-----------------------------------------------')
    return name,price,rate,link_,quantity

# %%
def Details_Inner_Page(i,soup):
    next_page= soup.find('li',attrs={'class':'next'}).find('a').attrs['href']
    link[i]=link[i].split('/')
    link[i][-1]=next_page
    link[i]='/'.join(link[i])

# %%
def Get_Books(L):
    for i in range(len(link)):
        art,soup,Name,url = Details_Category(i)
        f.write(f'Name Of Category: {Name}\nLink Of Category: {url}\n')
        f.write('*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*\n')
        for j in art:
            name,price,rate,link_,quantity = Details_Page(j)
            f.write(f'Book name: {name}\nPrice: {price}\nRate: {rates[rate]}\nquantity: {quantity}\nBook link: {link_}\n')
            f.write('*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+**+*+*+*+*+*+*+*+*+*+*+*+*+*+\n')  
        try:
            while(True):
                pages=soup.find('li',attrs={'class':'current'}).get_text().strip()
                if(int(pages[5:7])<=int(pages[-2:])):
                    Details_Inner_Page(i,soup)
                    art,soup,Name,url = Details_Category(i)
                    f.write(f'Name Of Category: {Name}\nLink Of Category: {url}\n')
                    f.write('*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*\n')
                    for j in art:
                        name,price,rate,link_,quantity = Details_Page(j)
                        f.write(f'Book name: {name}\nPrice: {price}\nRate: {rates[rate]}\nquantity: {quantity}\nBook link: {link_}\n')
                        f.write('*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+**+*+*+*+*+*+*+*+*+*+*+*+*+*+\n')
                else:
                    break 
        except:
            continue

# %%
Get_Books(L)
# Out:
# Name Of Category: Travel
# Link Of Category: https://books.toscrape.com/catalogue/category/books/travel_2/index.html
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Book name: It's Only the Himalayas
# Price: 45.17
# Rate: 2
# Book link: https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html
# quantity: 19
#
# -----------------------------------------------
# Book name: Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and Beyond
# Price: 49.43
# Rate: 4
# Book link: https://books.toscrape.com/catalogue/full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html
# quantity: 15
#
# -----------------------------------------------
# Book name: See America: A Celebration of Our National Parks & Treasured Sites
# Price: 48.87
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/see-america-a-celebration-of-our-national-parks-treasured-sites_732/index.html
# quantity: 14
#
# -----------------------------------------------
# Book name: Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel
# Price: 36.94
# Rate: 2
# Book link: https://books.toscrape.com/catalogue/vagabonding-an-uncommon-guide-to-the-art-of-long-term-world-travel_552/index.html
# quantity: 8
#
# -----------------------------------------------
# Book name: Under the Tuscan Sun
# Price: 37.33
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/under-the-tuscan-sun_504/index.html
# quantity: 7
#
# -----------------------------------------------
# Book name: A Summer In Europe
# Price: 44.34
# Rate: 2
# Book link: https://books.toscrape.com/catalogue/a-summer-in-europe_458/index.html
# quantity: 7
#
# -----------------------------------------------
# Book name: The Great Railway Bazaar
# Price: 30.54
# Rate: 1
# Book link: https://books.toscrape.com/catalogue/the-great-railway-bazaar_446/index.html
# quantity: 6
#
# -----------------------------------------------
# Book name: A Year in Provence (Provence #1)
# Price: 56.88
# Rate: 4
# Book link: https://books.toscrape.com/catalogue/a-year-in-provence-provence-1_421/index.html
# quantity: 6
#
# -----------------------------------------------
# Book name: The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)
# Price: 23.21
# Rate: 1
# Book link: https://books.toscrape.com/catalogue/the-road-to-little-dribbling-adventures-of-an-american-in-britain-notes-from-a-small-island-2_277/index.html
# quantity: 3
#
# -----------------------------------------------
# Book name: Neither Here nor There: Travels in Europe
# Price: 38.95
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/neither-here-nor-there-travels-in-europe_198/index.html
# quantity: 3
#
# -----------------------------------------------
# Book name: 1,000 Places to See Before You Die
# Price: 26.08
# Rate: 5
# Book link: https://books.toscrape.com/catalogue/1000-places-to-see-before-you-die_1/index.html
# quantity: 1
#
# -----------------------------------------------
# Name Of Category: Mystery
# Link Of Category: https://books.toscrape.com/catalogue/category/books/mystery_3/index.html
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Book name: Sharp Objects
# Price: 47.82
# Rate: 4
# Book link: https://books.toscrape.com/catalogue/sharp-objects_997/index.html
# quantity: 20
#
# -----------------------------------------------
# Book name: In a Dark, Dark Wood
# Price: 19.63
# Rate: 1
# Book link: https://books.toscrape.com/catalogue/in-a-dark-dark-wood_963/index.html
# quantity: 18
#
# -----------------------------------------------
# Book name: The Past Never Ends
# Price: 56.5
# Rate: 4
# Book link: https://books.toscrape.com/catalogue/the-past-never-ends_942/index.html
# quantity: 16
#
# -----------------------------------------------
# Book name: A Murder in Time
# Price: 16.64
# Rate: 1
# Book link: https://books.toscrape.com/catalogue/a-murder-in-time_877/index.html
# quantity: 16
#
# -----------------------------------------------
# Book name: The Murder of Roger Ackroyd (Hercule Poirot #4)
# Price: 44.1
# Rate: 4
# Book link: https://books.toscrape.com/catalogue/the-murder-of-roger-ackroyd-hercule-poirot-4_852/index.html
# quantity: 15
#
# -----------------------------------------------
# Book name: The Last Mile (Amos Decker #2)
# Price: 54.21
# Rate: 2
# Book link: https://books.toscrape.com/catalogue/the-last-mile-amos-decker-2_754/index.html
# quantity: 14
#
# -----------------------------------------------
# Book name: That Darkness (Gardiner and Renner #1)
# Price: 13.92
# Rate: 1
# Book link: https://books.toscrape.com/catalogue/that-darkness-gardiner-and-renner-1_743/index.html
# quantity: 14
#
# -----------------------------------------------
# Book name: Tastes Like Fear (DI Marnie Rome #3)
# Price: 10.69
# Rate: 1
# Book link: https://books.toscrape.com/catalogue/tastes-like-fear-di-marnie-rome-3_742/index.html
# quantity: 14
#
# -----------------------------------------------
# Book name: A Time of Torment (Charlie Parker #14)
# Price: 48.35
# Rate: 5
# Book link: https://books.toscrape.com/catalogue/a-time-of-torment-charlie-parker-14_657/index.html
# quantity: 14
#
# -----------------------------------------------
# Book name: A Study in Scarlet (Sherlock Holmes #1)
# Price: 16.73
# Rate: 2
# Book link: https://books.toscrape.com/catalogue/a-study-in-scarlet-sherlock-holmes-1_656/index.html
# quantity: 14
#
# -----------------------------------------------
# Book name: Poisonous (Max Revere Novels #3)
# Price: 26.8
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/poisonous-max-revere-novels-3_627/index.html
# quantity: 12
#
# -----------------------------------------------
# Book name: Murder at the 42nd Street Library (Raymond Ambler #1)
# Price: 54.36
# Rate: 4
# Book link: https://books.toscrape.com/catalogue/murder-at-the-42nd-street-library-raymond-ambler-1_624/index.html
# quantity: 12
#
# -----------------------------------------------
# Book name: Most Wanted
# Price: 35.28
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/most-wanted_623/index.html
# quantity: 12
#
# -----------------------------------------------
# Book name: Hide Away (Eve Duncan #20)
# Price: 11.84
# Rate: 1
# Book link: https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html
# quantity: 12
#
# -----------------------------------------------
# Book name: Boar Island (Anna Pigeon #19)
# Price: 59.48
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/boar-island-anna-pigeon-19_613/index.html
# quantity: 12
#
# -----------------------------------------------
# Book name: The Widow
# Price: 27.26
# Rate: 2
# Book link: https://books.toscrape.com/catalogue/the-widow_609/index.html
# quantity: 11
#
# -----------------------------------------------
# Book name: Playing with Fire
# Price: 13.71
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/playing-with-fire_602/index.html
# quantity: 11
#
# -----------------------------------------------
# Book name: What Happened on Beale Street (Secrets of the South Mysteries #2)
# Price: 25.37
# Rate: 5
# Book link: https://books.toscrape.com/catalogue/what-happened-on-beale-street-secrets-of-the-south-mysteries-2_506/index.html
# quantity: 7
#
# -----------------------------------------------
# Book name: The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)
# Price: 52.3
# Rate: 5
# Book link: https://books.toscrape.com/catalogue/the-bachelor-girls-guide-to-murder-herringford-and-watts-mysteries-1_491/index.html
# quantity: 7
#
# -----------------------------------------------
# Book name: Delivering the Truth (Quaker Midwife Mystery #1)
# Price: 20.89
# Rate: 4
# Book link: https://books.toscrape.com/catalogue/delivering-the-truth-quaker-midwife-mystery-1_464/index.html
# quantity: 7
#
# -----------------------------------------------
# Name Of Category: Mystery
# Link Of Category: https://books.toscrape.com/catalogue/category/books/mystery_3/page-2.html
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Book name: The Mysterious Affair at Styles (Hercule Poirot #1)
# Price: 24.8
# Rate: 4
# Book link: https://books.toscrape.com/catalogue/the-mysterious-affair-at-styles-hercule-poirot-1_452/index.html
# quantity: 6
#
# -----------------------------------------------
# Book name: In the Woods (Dublin Murder Squad #1)
# Price: 38.38
# Rate: 2
# Book link: https://books.toscrape.com/catalogue/in-the-woods-dublin-murder-squad-1_433/index.html
# quantity: 6
#
# -----------------------------------------------
# Book name: The Silkworm (Cormoran Strike #2)
# Price: 23.05
# Rate: 5
# Book link: https://books.toscrape.com/catalogue/the-silkworm-cormoran-strike-2_280/index.html
# quantity: 3
#
# -----------------------------------------------
# Book name: The Exiled
# Price: 43.45
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/the-exiled_247/index.html
# quantity: 3
#
# -----------------------------------------------
# Book name: The Cuckoo's Calling (Cormoran Strike #1)
# Price: 19.21
# Rate: 1
# Book link: https://books.toscrape.com/catalogue/the-cuckoos-calling-cormoran-strike-1_239/index.html
# quantity: 3
#
# -----------------------------------------------
# Book name: Extreme Prey (Lucas Davenport #26)
# Price: 25.4
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/extreme-prey-lucas-davenport-26_154/index.html
# quantity: 3
#
# -----------------------------------------------
# Book name: Career of Evil (Cormoran Strike #3)
# Price: 24.72
# Rate: 2
# Book link: https://books.toscrape.com/catalogue/career-of-evil-cormoran-strike-3_137/index.html
# quantity: 3
#
# -----------------------------------------------
# Book name: The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)
# Price: 57.7
# Rate: 4
# Book link: https://books.toscrape.com/catalogue/the-no-1-ladies-detective-agency-no-1-ladies-detective-agency-1_76/index.html
# quantity: 1
#
# -----------------------------------------------
# Book name: The Girl You Lost
# Price: 12.29
# Rate: 5
# Book link: https://books.toscrape.com/catalogue/the-girl-you-lost_66/index.html
# quantity: 1
#
# -----------------------------------------------
# Book name: The Girl In The Ice (DCI Erika Foster #1)
# Price: 15.85
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/the-girl-in-the-ice-dci-erika-foster-1_65/index.html
# quantity: 1
#
# -----------------------------------------------
# Book name: Blood Defense (Samantha Brinkman #1)
# Price: 20.3
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/blood-defense-samantha-brinkman-1_8/index.html
# quantity: 1
#
# -----------------------------------------------
# Book name: 1st to Die (Women's Murder Club #1)
# Price: 53.98
# Rate: 1
# Book link: https://books.toscrape.com/catalogue/1st-to-die-womens-murder-club-1_2/index.html
# quantity: 1
#
# -----------------------------------------------
# Name Of Category: Historical Fiction
# Link Of Category: https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Book name: Tipping the Velvet
# Price: 53.74
# Rate: 1
# Book link: https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html
# quantity: 20
#
# -----------------------------------------------
# Book name: Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton
# Price: 29.69
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/forever-and-forever-the-courtship-of-henry-longfellow-and-fanny-appleton_894/index.html
# quantity: 16
#
# -----------------------------------------------
# Book name: A Flight of Arrows (The Pathfinders #2)
# Price: 55.53
# Rate: 5
# Book link: https://books.toscrape.com/catalogue/a-flight-of-arrows-the-pathfinders-2_876/index.html
# quantity: 16
#
# -----------------------------------------------
# Book name: The House by the Lake
# Price: 36.95
# Rate: 1
# Book link: https://books.toscrape.com/catalogue/the-house-by-the-lake_846/index.html
# quantity: 15
#
# -----------------------------------------------
# Book name: Mrs. Houdini
# Price: 30.25
# Rate: 5
# Book link: https://books.toscrape.com/catalogue/mrs-houdini_821/index.html
# quantity: 15
#
# -----------------------------------------------
# Book name: The Marriage of Opposites
# Price: 28.08
# Rate: 4
# Book link: https://books.toscrape.com/catalogue/the-marriage-of-opposites_759/index.html
# quantity: 14
#
# -----------------------------------------------
# Book name: Glory over Everything: Beyond The Kitchen House
# Price: 45.84
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/glory-over-everything-beyond-the-kitchen-house_696/index.html
# quantity: 14
#
# -----------------------------------------------
# Book name: Love, Lies and Spies
# Price: 20.55
# Rate: 2
# Book link: https://books.toscrape.com/catalogue/love-lies-and-spies_622/index.html
# quantity: 12
#
# -----------------------------------------------
# Book name: A Paris Apartment
# Price: 39.01
# Rate: 4
# Book link: https://books.toscrape.com/catalogue/a-paris-apartment_612/index.html
# quantity: 12
#
# -----------------------------------------------
# Book name: Lilac Girls
# Price: 17.28
# Rate: 2
# Book link: https://books.toscrape.com/catalogue/lilac-girls_597/index.html
# quantity: 11
#
# -----------------------------------------------
# Book name: The Constant Princess (The Tudor Court #1)
# Price: 16.62
# Rate: 3
# Book link: https://books.toscrape.com/catalogue/the-constant-princess-the-tudor-court-1_493/index.html
# quantity: 7
#
# -----------------------------------------------

# %%
f.close()
